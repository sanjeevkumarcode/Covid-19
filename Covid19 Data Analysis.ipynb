# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("D:\covid19_italy_province.csv")

# %%
data.head()
# Out:
#    SNo                 Date Country  RegionCode RegionName  ProvinceCode  \
# 0    0  2020-02-24T18:00:00     ITA          13    Abruzzo            66
# 1    1  2020-02-24T18:00:00     ITA          13    Abruzzo            67
# 2    2  2020-02-24T18:00:00     ITA          13    Abruzzo            68
# 3    3  2020-02-24T18:00:00     ITA          13    Abruzzo            69
# 4    4  2020-02-24T18:00:00     ITA          13    Abruzzo           979
#
#                            ProvinceName ProvinceAbbreviation   Latitude  \
# 0                              L'Aquila                   AQ  42.351222
# 1                                Teramo                   TE  42.658918
# 2                               Pescara                   PE  42.464584
# 3                                Chieti                   CH  42.351032
# 4  In fase di definizione/aggiornamento                  NaN        NaN
#
#    Longitude  TotalPositiveCases
# 0  13.398438                   0
# ...

# %%
data.drop(["Latitude","RegionName"],inplace=True,axis=1)

# %%
data.head()
# Out:
#    SNo                 Date Country  RegionCode  ProvinceCode  \
# 0    0  2020-02-24T18:00:00     ITA          13            66
# 1    1  2020-02-24T18:00:00     ITA          13            67
# 2    2  2020-02-24T18:00:00     ITA          13            68
# 3    3  2020-02-24T18:00:00     ITA          13            69
# 4    4  2020-02-24T18:00:00     ITA          13           979
#
#                            ProvinceName ProvinceAbbreviation  Longitude  \
# 0                              L'Aquila                   AQ  13.398438
# 1                                Teramo                   TE  13.704400
# 2                               Pescara                   PE  14.213648
# 3                                Chieti                   CH  14.167546
# 4  In fase di definizione/aggiornamento                  NaN        NaN
#
#    TotalPositiveCases
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'ProvinceCode', 'ProvinceName',
#        'ProvinceAbbreviation', 'Longitude', 'TotalPositiveCases'],
#       dtype='object')

# %%
data.describe()
# Out:
#                 SNo    RegionCode  ProvinceCode     Longitude  \
# count  40201.000000  40201.000000  40201.000000  30709.000000
# mean   20100.000000     10.357354    266.261188     12.096599
# std    11605.173423      5.993795    383.221679      2.660590
# min        0.000000      1.000000      1.000000      7.320149
# 25%    10050.000000      5.000000     36.000000      9.828190
# 50%    20100.000000      9.000000     71.000000     12.104734
# 75%    30150.000000     16.000000    110.000000     14.167546
# max    40200.000000     22.000000    999.000000     18.171897
#
#        TotalPositiveCases
# count        40201.000000
# mean          2563.579961
# std           6884.484083
# min              0.000000
# 25%            103.000000
# 50%            642.000000
# 75%           2605.000000
# max         158717.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40201 entries, 0 to 40200
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   SNo                   40201 non-null  int64
#  1   Date                  40201 non-null  object
#  2   Country               40201 non-null  object
#  3   RegionCode            40201 non-null  int64
#  4   ProvinceCode          40201 non-null  int64
#  5   ProvinceName          40201 non-null  object
#  6   ProvinceAbbreviation  30422 non-null  object
#  7   Longitude             30709 non-null  float64
#  8   TotalPositiveCases    40201 non-null  int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 2.8+ MB

# %%
data.isnull().sum()
# Out:
# SNo                        0
# Date                       0
# Country                    0
# RegionCode                 0
# ProvinceCode               0
# ProvinceName               0
# ProvinceAbbreviation    9779
# Longitude               9492
# TotalPositiveCases         0
# dtype: int64

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'ProvinceCode', 'ProvinceName',
#        'ProvinceAbbreviation', 'Longitude', 'TotalPositiveCases'],
#       dtype='object')

# %%
data1=pd.read_csv("D:\covid_19_india.csv")
data1
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
#Active Cases
data1['Active Cases'] = data1['Confirmed'] - (data1['Cured'] + data1['Deaths'])
data1
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
data1['Total Cases'] = data1['Confirmed'] + data1['Active Cases'] + data1['Cured'] + data1['Deaths']
data1
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
data1.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed', 'Active Cases', 'Total Cases'],
#       dtype='object')

# %%
data1.drop(["ConfirmedIndianNational","Time","Date"],inplace=True,axis=1)

# %%
data1.columns
# Out:
# Index(['Sno', 'State/UnionTerritory', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed', 'Active Cases', 'Total Cases'],
#       dtype='object')

# %%
sns.relplot(X="Total Cases", Y="Confirmed",data1=data1)

# %%
sns.pairplot(data1)

# %%
sns.relplot(X="Confirmed", Y="Cured",kind='line', data1=data1)

# %%
data1.columns
# Out:
# Index(['Sno', 'State/UnionTerritory', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed', 'Active Cases', 'Total Cases'],
#       dtype='object')

# %%
data1.columns
# Out:
# Index(['Sno', 'State/UnionTerritory', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed', 'Active Cases', 'Total Cases'],
#       dtype='object')

# %%
data1.Cured.max()
# Out:
# 6159676
